# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-1/router.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239412-lesson-5-router)

# %% [markdown]
# # Router
#
# ## Review
#
# We built a graph that uses `messages` as state and a chat model with bound tools.
#
# We saw that the graph can:
#
# * Return a tool call
# * Return a natural language response
#
# ## Goals
#
# We can think of this as a router, where the chat model routes between a direct response or a tool call based upon the user input.
#
# This is a simple example of an agent, where the LLM is directing the control flow either by calling a tool or just responding directly.
#
# ![Screenshot 2024-08-21 at 9.24.09 AM.png](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbac6543c3d4df239a4ed1_router1.png)
#
# Let's extend our graph to work with either output!
#
# For this, we can use two ideas:
#
# (1) Add a node that will call our tool.
#
# (2) Add a conditional edge that will look at the chat model output, and route to our tool calling node or simply end if no tool call is performed.

# %%
# %pip install -U langchain_openai langchain_core langgraph langgraph-prebuilt
# Out:
# Requirement already satisfied: langchain_openai in /workspace/.venv/lib/python3.11/site-packages (0.3.33)
# Requirement already satisfied: langchain_core in /workspace/.venv/lib/python3.11/site-packages (0.3.76)
# Requirement already satisfied: langgraph in /workspace/.venv/lib/python3.11/site-packages (0.6.7)
# Requirement already satisfied: langgraph-prebuilt in /workspace/.venv/lib/python3.11/site-packages (0.6.4)
# Collecting mermaid
#   Using cached mermaid-0.3.2-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: openai<2.0.0,>=1.104.2 in /workspace/.venv/lib/python3.11/site-packages (from langchain_openai) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /workspace/.venv/lib/python3.11/site-packages (from langchain_openai) (0.11.0)
# Requirement already satisfied: langsmith>=0.3.45 in /workspace/.venv/lib/python3.11/site-packages (from langchain_core) (0.4.31)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /workspace/.venv/lib/python3.11/site-packages (from langchain_core) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /workspace/.venv/lib/python3.11/site-packages (from langchain_core) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /workspace/.venv/lib/python3.11/site-packages (from langchain_core) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.7 in /workspace/.venv/lib/python3.11/site-packages (from langchain_core) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in /workspace/.venv/lib/python3.11/site-packages (from langchain_core) (25.0)
# Requirement already satisfied: pydantic>=2.7.4 in /workspace/.venv/lib/python3.11/site-packages (from langchain_core) (2.11.9)
# Requirement already satisfied: langgraph-checkpoint<3.0.0,>=2.1.0 in /workspace/.venv/lib/python3.11/site-packages (from langgraph) (2.1.1)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /workspace/.venv/lib/python3.11/site-packages (from langgraph) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /workspace/.venv/lib/python3.11/site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: ipython in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (9.5.0)
# Collecting jupyter (from mermaid)
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: ipykernel in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (6.30.1)
# Requirement already satisfied: numpy in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (2.3.3)
# Requirement already satisfied: pynrrd in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (1.1.3)
# Requirement already satisfied: future in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (1.0.0)
# Requirement already satisfied: cython in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (3.1.4)
# Requirement already satisfied: scikit-image in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (0.25.2)
# Requirement already satisfied: tabulate in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (0.9.0)
# Requirement already satisfied: termcolor in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (3.1.0)
# Requirement already satisfied: cffi in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (2.0.0)
# Collecting itk (from mermaid)
#   Using cached itk-5.4.4.post1-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting torch>=1.7torchvision (from mermaid)
#   Using cached torch-2.8.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Requirement already satisfied: pandas in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (2.3.2)
# Requirement already satisfied: matplotlib in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (3.10.6)
# Requirement already satisfied: scipy in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (1.16.2)
# Requirement already satisfied: openpyxl in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (3.1.5)
# Requirement already satisfied: sphinx-gallery==0.3.1 in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (0.3.1)
# Requirement already satisfied: sphinx in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (8.1.3)
# Collecting nbsphinx (from mermaid)
#   Using cached nbsphinx-0.9.7-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pandoc in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (2.4)
# Requirement already satisfied: pypandoc in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (1.15)
# Requirement already satisfied: statsmodels in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (0.14.5)
# Requirement already satisfied: progressbar2 in /workspace/.venv/lib/python3.11/site-packages (from mermaid) (4.5.0)
# Requirement already satisfied: setuptools in /workspace/.venv/lib/python3.11/site-packages (from sphinx-gallery==0.3.1->mermaid) (65.5.1)
# Requirement already satisfied: pillow in /workspace/.venv/lib/python3.11/site-packages (from sphinx-gallery==0.3.1->mermaid) (11.3.0)
# Requirement already satisfied: jsonpointer>=1.9 in /workspace/.venv/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /workspace/.venv/lib/python3.11/site-packages (from langgraph-checkpoint<3.0.0,>=2.1.0->langgraph) (1.10.0)
# Requirement already satisfied: httpx>=0.25.2 in /workspace/.venv/lib/python3.11/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /workspace/.venv/lib/python3.11/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /workspace/.venv/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /workspace/.venv/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain_core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /workspace/.venv/lib/python3.11/site-packages (from langsmith>=0.3.45->langchain_core) (0.25.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /workspace/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain_openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /workspace/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /workspace/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain_openai) (0.11.0)
# Requirement already satisfied: sniffio in /workspace/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /workspace/.venv/lib/python3.11/site-packages (from openai<2.0.0,>=1.104.2->langchain_openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /workspace/.venv/lib/python3.11/site-packages (from pydantic>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /workspace/.venv/lib/python3.11/site-packages (from pydantic>=2.7.4->langchain_core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /workspace/.venv/lib/python3.11/site-packages (from pydantic>=2.7.4->langchain_core) (0.4.1)
# Requirement already satisfied: regex>=2022.1.18 in /workspace/.venv/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain_openai) (2025.9.18)
# Requirement already satisfied: filelock in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (3.19.1)
# Requirement already satisfied: sympy>=1.13.3 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (1.14.0)
# Requirement already satisfied: networkx in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (3.5)
# Requirement already satisfied: jinja2 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (3.1.6)
# Requirement already satisfied: fsspec in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (2025.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (10.3.9.90)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch>=1.7torchvision->mermaid)
#   Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /workspace/.venv/lib/python3.11/site-packages (from torch>=1.7torchvision->mermaid) (3.4.0)
# Requirement already satisfied: pycparser in /workspace/.venv/lib/python3.11/site-packages (from cffi->mermaid) (2.23)
# Requirement already satisfied: comm>=0.1.1 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel->mermaid) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel->mermaid) (1.8.17)
# Requirement already satisfied: jupyter-client>=8.0.0 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel->mermaid) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel->mermaid) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel->mermaid) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel->mermaid) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel->mermaid) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel->mermaid) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel->mermaid) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in /workspace/.venv/lib/python3.11/site-packages (from ipykernel->mermaid) (5.14.3)
# Requirement already satisfied: decorator in /workspace/.venv/lib/python3.11/site-packages (from ipython->mermaid) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /workspace/.venv/lib/python3.11/site-packages (from ipython->mermaid) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /workspace/.venv/lib/python3.11/site-packages (from ipython->mermaid) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /workspace/.venv/lib/python3.11/site-packages (from ipython->mermaid) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /workspace/.venv/lib/python3.11/site-packages (from ipython->mermaid) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /workspace/.venv/lib/python3.11/site-packages (from ipython->mermaid) (2.19.2)
# Requirement already satisfied: stack_data in /workspace/.venv/lib/python3.11/site-packages (from ipython->mermaid) (0.6.3)
# Requirement already satisfied: itk-core==5.4.4.post1 in /workspace/.venv/lib/python3.11/site-packages (from itk->mermaid) (5.4.4.post1)
# Requirement already satisfied: itk-numerics==5.4.4.post1 in /workspace/.venv/lib/python3.11/site-packages (from itk->mermaid) (5.4.4.post1)
# Requirement already satisfied: itk-io==5.4.4.post1 in /workspace/.venv/lib/python3.11/site-packages (from itk->mermaid) (5.4.4.post1)
# Collecting itk-filtering==5.4.4.post1 (from itk->mermaid)
#   Using cached itk_filtering-5.4.4.post1-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting itk-registration==5.4.4.post1 (from itk->mermaid)
#   Using cached itk_registration-5.4.4.post1-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting itk-segmentation==5.4.4.post1 (from itk->mermaid)
#   Using cached itk_segmentation-5.4.4.post1-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting notebook (from jupyter->mermaid)
#   Using cached notebook-7.4.7-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter->mermaid)
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter->mermaid)
#   Using cached nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Collecting ipywidgets (from jupyter->mermaid)
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting jupyterlab (from jupyter->mermaid)
#   Using cached jupyterlab-4.4.9-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /workspace/.venv/lib/python3.11/site-packages (from matplotlib->mermaid) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /workspace/.venv/lib/python3.11/site-packages (from matplotlib->mermaid) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /workspace/.venv/lib/python3.11/site-packages (from matplotlib->mermaid) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /workspace/.venv/lib/python3.11/site-packages (from matplotlib->mermaid) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /workspace/.venv/lib/python3.11/site-packages (from matplotlib->mermaid) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /workspace/.venv/lib/python3.11/site-packages (from matplotlib->mermaid) (2.9.0.post0)
# Requirement already satisfied: docutils>=0.18.1 in /workspace/.venv/lib/python3.11/site-packages (from nbsphinx->mermaid) (0.21.2)
# Collecting nbformat (from nbsphinx->mermaid)
#   Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /workspace/.venv/lib/python3.11/site-packages (from sphinx->mermaid) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /workspace/.venv/lib/python3.11/site-packages (from sphinx->mermaid) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /workspace/.venv/lib/python3.11/site-packages (from sphinx->mermaid) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /workspace/.venv/lib/python3.11/site-packages (from sphinx->mermaid) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /workspace/.venv/lib/python3.11/site-packages (from sphinx->mermaid) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /workspace/.venv/lib/python3.11/site-packages (from sphinx->mermaid) (2.0.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /workspace/.venv/lib/python3.11/site-packages (from sphinx->mermaid) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /workspace/.venv/lib/python3.11/site-packages (from sphinx->mermaid) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /workspace/.venv/lib/python3.11/site-packages (from sphinx->mermaid) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /workspace/.venv/lib/python3.11/site-packages (from sphinx->mermaid) (1.4.1)
# Requirement already satisfied: et-xmlfile in /workspace/.venv/lib/python3.11/site-packages (from openpyxl->mermaid) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /workspace/.venv/lib/python3.11/site-packages (from pandas->mermaid) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /workspace/.venv/lib/python3.11/site-packages (from pandas->mermaid) (2025.2)
# Requirement already satisfied: plumbum in /workspace/.venv/lib/python3.11/site-packages (from pandoc->mermaid) (1.9.0)
# Requirement already satisfied: ply in /workspace/.venv/lib/python3.11/site-packages (from pandoc->mermaid) (3.11)
# Requirement already satisfied: python-utils>=3.8.1 in /workspace/.venv/lib/python3.11/site-packages (from progressbar2->mermaid) (3.9.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /workspace/.venv/lib/python3.11/site-packages (from scikit-image->mermaid) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /workspace/.venv/lib/python3.11/site-packages (from scikit-image->mermaid) (2025.9.20)
# Requirement already satisfied: lazy-loader>=0.4 in /workspace/.venv/lib/python3.11/site-packages (from scikit-image->mermaid) (0.4)
# Requirement already satisfied: patsy>=0.5.6 in /workspace/.venv/lib/python3.11/site-packages (from statsmodels->mermaid) (1.0.1)
# Requirement already satisfied: idna>=2.8 in /workspace/.venv/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.104.2->langchain_openai) (3.10)
# Requirement already satisfied: certifi in /workspace/.venv/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /workspace/.venv/lib/python3.11/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /workspace/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /workspace/.venv/lib/python3.11/site-packages (from jedi>=0.16->ipython->mermaid) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /workspace/.venv/lib/python3.11/site-packages (from jinja2->torch>=1.7torchvision->mermaid) (3.0.2)
# Requirement already satisfied: platformdirs>=2.5 in /workspace/.venv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->mermaid) (4.4.0)
# Requirement already satisfied: beautifulsoup4 in /workspace/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->mermaid) (4.14.0)
# Requirement already satisfied: bleach!=5.0.0 in /workspace/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->mermaid) (6.2.0)
# Requirement already satisfied: defusedxml in /workspace/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->mermaid) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /workspace/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->mermaid) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /workspace/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->mermaid) (3.1.4)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter->mermaid)
#   Using cached nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: pandocfilters>=1.4.1 in /workspace/.venv/lib/python3.11/site-packages (from nbconvert->jupyter->mermaid) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /workspace/.venv/lib/python3.11/site-packages (from nbformat->nbsphinx->mermaid) (2.21.2)
# Collecting jsonschema>=2.6 (from nbformat->nbsphinx->mermaid)
#   Using cached jsonschema-4.25.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /workspace/.venv/lib/python3.11/site-packages (from pexpect>4.3->ipython->mermaid) (0.7.0)
# Requirement already satisfied: wcwidth in /workspace/.venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->mermaid) (0.2.13)
# Requirement already satisfied: six>=1.5 in /workspace/.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->mermaid) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /workspace/.venv/lib/python3.11/site-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain_core) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspace/.venv/lib/python3.11/site-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain_core) (1.26.20)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /workspace/.venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.7torchvision->mermaid) (1.3.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /workspace/.venv/lib/python3.11/site-packages (from ipywidgets->jupyter->mermaid) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /workspace/.venv/lib/python3.11/site-packages (from ipywidgets->jupyter->mermaid) (3.0.15)
# Requirement already satisfied: async-lru>=1.0.0 in /workspace/.venv/lib/python3.11/site-packages (from jupyterlab->jupyter->mermaid) (2.0.5)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->mermaid)
#   Using cached jupyter_lsp-2.3.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.4.0 (from jupyterlab->jupyter->mermaid)
#   Using cached jupyter_server-2.17.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter->mermaid)
#   Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim>=0.2 (from jupyterlab->jupyter->mermaid)
#   Using cached notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: executing>=1.2.0 in /workspace/.venv/lib/python3.11/site-packages (from stack_data->ipython->mermaid) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /workspace/.venv/lib/python3.11/site-packages (from stack_data->ipython->mermaid) (3.0.0)
# Requirement already satisfied: pure-eval in /workspace/.venv/lib/python3.11/site-packages (from stack_data->ipython->mermaid) (0.2.3)
# Requirement already satisfied: webencodings in /workspace/.venv/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->mermaid) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /workspace/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->mermaid) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /workspace/.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->mermaid) (25.3.0)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat->nbsphinx->mermaid)
#   Using cached jsonschema_specifications-2025.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: referencing>=0.28.4 in /workspace/.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->mermaid) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /workspace/.venv/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbsphinx->mermaid) (0.27.1)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid)
#   Using cached argon2_cffi-25.1.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid)
#   Using cached jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /workspace/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (1.8.0)
# Requirement already satisfied: json5>=0.9.0 in /workspace/.venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->mermaid) (0.12.1)
# Requirement already satisfied: soupsieve>1.2 in /workspace/.venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->mermaid) (2.8)
# Requirement already satisfied: argon2-cffi-bindings in /workspace/.venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (25.1.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /workspace/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /workspace/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /workspace/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (0.1.1)
# Requirement already satisfied: fqdn in /workspace/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (1.5.1)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /workspace/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (1.1.0)
# Requirement already satisfied: uri-template in /workspace/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /workspace/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (24.11.1)
# Requirement already satisfied: lark>=1.2.2 in /workspace/.venv/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (1.2.2)
# Requirement already satisfied: arrow>=0.15.0 in /workspace/.venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /workspace/.venv/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->mermaid) (2.9.0.20250822)
# Using cached mermaid-0.3.2-py3-none-any.whl (1.2 MB)
# Using cached torch-2.8.0-cp311-cp311-manylinux_2_28_x86_64.whl (888.1 MB)
# Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
# Using cached itk-5.4.4.post1-cp311-abi3-manylinux_2_28_x86_64.whl (16 kB)
# Using cached itk_filtering-5.4.4.post1-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (67.8 MB)
# Using cached itk_registration-5.4.4.post1-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (28.5 MB)
# Using cached itk_segmentation-5.4.4.post1-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (15.9 MB)
# Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Using cached nbsphinx-0.9.7-py3-none-any.whl (31 kB)
# Using cached nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Using cached jupyterlab-4.4.9-py3-none-any.whl (12.3 MB)
# Using cached notebook-7.4.7-py3-none-any.whl (14.3 MB)
# Using cached jsonschema-4.25.1-py3-none-any.whl (90 kB)
# Using cached jupyter_lsp-2.3.0-py3-none-any.whl (76 kB)
# Using cached jupyter_server-2.17.0-py3-none-any.whl (388 kB)
# Using cached jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Using cached nbclient-0.10.2-py3-none-any.whl (25 kB)
# Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Using cached argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Using cached jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Using cached jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# DEPRECATION: mermaid 0.3.2 has a non-standard dependency specifier torch>=1.7torchvision. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of mermaid or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: nvidia-cusolver-cu12, jsonschema-specifications, torch, jsonschema, itk-filtering, isoduration, ipywidgets, argon2-cffi, nbformat, jupyter-console, itk-segmentation, itk-registration, nbclient, jupyter-events, itk, nbconvert, nbsphinx, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter, mermaid
# Successfully installed argon2-cffi-25.1.0 ipywidgets-8.1.7 isoduration-20.11.0 itk-5.4.4.post1 itk-filtering-5.4.4.post1 itk-registration-5.4.4.post1 itk-segmentation-5.4.4.post1 jsonschema-4.25.1 jsonschema-specifications-2025.9.1 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.0 jupyter-lsp-2.3.0 jupyter-server-2.17.0 jupyterlab-4.4.9 jupyterlab-server-2.27.3 mermaid-0.3.2 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 nbsphinx-0.9.7 notebook-7.4.7 notebook-shim-0.2.4 nvidia-cusolver-cu12-11.7.3.90 torch-2.8.0
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %%
from langchain_openai import ChatOpenAI

def multiply(a: int, b: int) -> int:
    """Multiply a and b.

    Args:
        a: first int
        b: second int
    """
    return a * b

llm = ChatOpenAI(model="gpt-4o")
llm_with_tools = llm.bind_tools([multiply])
llm_with_tools
# Out:
# RunnableBinding(bound=ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x782c706e3750>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x782c70c716d0>, root_client=<openai.OpenAI object at 0x782c70c62250>, root_async_client=<openai.AsyncOpenAI object at 0x782c70c63b90>, model_name='gpt-4o', model_kwargs={}, openai_api_key=SecretStr('**********')), kwargs={'tools': [{'type': 'function', 'function': {'name': 'multiply', 'description': 'Multiply a and b.', 'parameters': {'properties': {'a': {'description': 'first int', 'type': 'integer'}, 'b': {'description': 'second int', 'type': 'integer'}}, 'required': ['a', 'b'], 'type': 'object'}}}]}, config={}, config_factories=[])

# %% [markdown]
#  We use the [built-in `ToolNode`](https://langchain-ai.github.io/langgraph/reference/prebuilt/?h=tools+condition#toolnode) and simply pass a list of our tools to initialize it.
#
#  We use the [built-in `tools_condition`](https://langchain-ai.github.io/langgraph/reference/prebuilt/?h=tools+condition#tools_condition) as our conditional edge.

# %%
from IPython.display import Image, display
from langgraph.graph import StateGraph, START, END
from langgraph.graph import MessagesState
from langgraph.prebuilt import ToolNode
from langgraph.prebuilt import tools_condition

# Node
def tool_calling_llm(state: MessagesState):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

# Build graph
builder = StateGraph(MessagesState)
builder.add_node("tool_calling_llm", tool_calling_llm)
builder.add_node("tools", ToolNode([multiply]))
builder.add_edge(START, "tool_calling_llm")
builder.add_conditional_edges(
    "tool_calling_llm",
    # If the latest message (result) from assistant is a tool call -> tools_condition routes to tools
    # If the latest message (result) from assistant is a not a tool call -> tools_condition routes to END
    tools_condition,
)
builder.add_edge("tools", END)
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
from langchain_core.messages import HumanMessage
messages = [HumanMessage(content="Hello, what is 2 multiplied by 2?")]
messages = graph.invoke({"messages": messages})
for m in messages['messages']:
    m.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Hello, what is 2 multiplied by 2?
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_Vdua64B5SArVGcOSDvqLU4u5)
#  Call ID: call_Vdua64B5SArVGcOSDvqLU4u5
#   Args:
#     a: 2
#     b: 2
# ================================= Tool Message =================================
# Name: multiply
#
# 4

# %% [markdown]
# Now, we can see that the graph runs the tool!
#
# It responds with a `ToolMessage`.
#
# ## LangGraph Studio
#
# **⚠️ DISCLAIMER**
#
# Since the filming of these videos, we've updated Studio so that it can be run locally and opened in your browser. This is now the preferred way to run Studio (rather than using the Desktop App as shown in the video). See documentation [here](https://langchain-ai.github.io/langgraph/concepts/langgraph_studio/#local-development-server) on the local development server and [here](https://langchain-ai.github.io/langgraph/how-tos/local-studio/#run-the-development-server). To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the Studio UI: `https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024`.
# Load the `router` in Studio, which uses `module-1/studio/router.py` set in `module-1/studio/langgraph.json`.

# %%
if 'google.colab' in str(get_ipython()):
    raise Exception("Unfortunately LangGraph Studio is currently not supported on Google Colab")
